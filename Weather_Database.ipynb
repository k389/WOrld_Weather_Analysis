# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the time module
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 586

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#for i in range(len(cities)):
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    #city_weather = requests.get(city_url)
    print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #if it is raining, get the amount of rainfall in inches for the last three hours. If it is not raining, add 0 inches for the city
        
        try:
            #city_weather['weather'][0]['main'] == 'Rain'
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        # if it is snowing, get the amount of snow in inches for the last three hours. If it is not snowing, add 0 inches for the city.
        try:
        #city_weather['weather'][0]['main'] == 'Snow'
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Rain inches (last 3 hrs)":city_rain,
                          "Snow inches (last 3 hrs)":city_snow,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=butaritari
# Processing Record 1 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=marcona
# Processing Record 2 of Set 1 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bathsheba
# Processing Record 3 of Set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=yellowknife
# Processing Record 4 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kaitangata
# Processing Record 5 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=newberry
# Processing Record 6 of Set 1 | newberry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=avarua
# Processing Record 7 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=luderitz
# Processing Record 8 of Set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kapaa
# Processing Record 9 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bluff
# Processing Record 10 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=istmina
# Processing Record 11 of Set 1 | istmina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=punta arenas
# Processing Record 12 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=new norfolk
# Processing Record 13 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sisimiut
# Processing Record 14 of Set 1 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saint george
# Processing Record 15 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=poshtove
# Processing Record 16 of Set 1 | poshtove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=narsaq
# Processing Record 17 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=albany
# Processing Record 18 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=busselton
# Processing Record 19 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ushuaia
# Processing Record 20 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cape town
# Processing Record 21 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saskylakh
# Processing Record 22 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bijie
# Processing Record 23 of Set 1 | bijie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vaini
# Processing Record 24 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nanortalik
# Processing Record 25 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kyren
# Processing Record 26 of Set 1 | kyren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ilulissat
# Processing Record 27 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=almaznyy
# Processing Record 28 of Set 1 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=rikitea
# Processing Record 29 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kibondo
# Processing Record 30 of Set 1 | kibondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port hedland
# Processing Record 31 of Set 1 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=thompson
# Processing Record 32 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=raudeberg
# Processing Record 33 of Set 1 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mataura
# Processing Record 34 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=baykit
# Processing Record 35 of Set 1 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=aswan
# Processing Record 36 of Set 1 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=salinas
# Processing Record 37 of Set 1 | salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hermanus
# Processing Record 38 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=japura
# Processing Record 39 of Set 1 | japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cabra
# Processing Record 40 of Set 1 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=jamestown
# Processing Record 41 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=labuhan
# Processing Record 42 of Set 1 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=atar
# Processing Record 43 of Set 1 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=samana
# Processing Record 44 of Set 1 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=zhigansk
# Processing Record 45 of Set 1 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=balikpapan
# Processing Record 46 of Set 1 | balikpapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saleaula
# Processing Record 47 of Set 1 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ewa beach
# Processing Record 48 of Set 1 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=khatanga
# Processing Record 49 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=quelimane
# Processing Record 50 of Set 1 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=wonthaggi
# Processing Record 1 of Set 2 | wonthaggi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=babanusah
# Processing Record 2 of Set 2 | babanusah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=clyde river
# Processing Record 3 of Set 2 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sitka
# Processing Record 4 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=barentsburg
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=los llanos de aridane
# Processing Record 6 of Set 2 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=arraial do cabo
# Processing Record 7 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=jaque
# Processing Record 8 of Set 2 | jaque
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port elizabeth
# Processing Record 9 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bubaque
# Processing Record 10 of Set 2 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=fairbanks
# Processing Record 11 of Set 2 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kavieng
# Processing Record 12 of Set 2 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hofn
# Processing Record 13 of Set 2 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bethel
# Processing Record 14 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=belushya guba
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=fonte boa
# Processing Record 16 of Set 2 | fonte boa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hunza
# Processing Record 17 of Set 2 | hunza
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=oyama
# Processing Record 18 of Set 2 | oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mikhaylovka
# Processing Record 19 of Set 2 | mikhaylovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=dikson
# Processing Record 20 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=illoqqortoormiut
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tortoli
# Processing Record 22 of Set 2 | tortoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=castro
# Processing Record 23 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mys shmidta
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tuatapere
# Processing Record 25 of Set 2 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kahului
# Processing Record 26 of Set 2 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=remanso
# Processing Record 27 of Set 2 | remanso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pisco
# Processing Record 28 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=roura
# Processing Record 29 of Set 2 | roura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=yeppoon
# Processing Record 30 of Set 2 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mocambique
# Processing Record 31 of Set 2 | mocambique
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=east london
# Processing Record 32 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tasiilaq
# Processing Record 33 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=qaanaaq
# Processing Record 34 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port alfred
# Processing Record 35 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=oranjemund
# Processing Record 36 of Set 2 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=amderma
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=san cristobal
# Processing Record 38 of Set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hobart
# Processing Record 39 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tura
# Processing Record 40 of Set 2 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=upernavik
# Processing Record 41 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kimbe
# Processing Record 42 of Set 2 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=petropavlovsk-kamchatskiy
# Processing Record 43 of Set 2 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tsihombe
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=san quintin
# Processing Record 45 of Set 2 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=korla
# Processing Record 46 of Set 2 | korla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lolua
# Processing Record 47 of Set 2 | lolua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saint-philippe
# Processing Record 48 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=constitucion
# Processing Record 49 of Set 2 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=komsomolskiy
# Processing Record 50 of Set 2 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kihei
# Processing Record 1 of Set 3 | kihei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=springdale
# Processing Record 2 of Set 3 | springdale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cherskiy
# Processing Record 3 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=atuona
# Processing Record 4 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ribeira grande
# Processing Record 5 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=chapais
# Processing Record 6 of Set 3 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=azimur
# Processing Record 7 of Set 3 | azimur
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=joensuu
# Processing Record 8 of Set 3 | joensuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=muroto
# Processing Record 9 of Set 3 | muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=poum
# Processing Record 10 of Set 3 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=norman wells
# Processing Record 11 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=loa janan
# Processing Record 12 of Set 3 | loa janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=geraldton
# Processing Record 13 of Set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pacific grove
# Processing Record 14 of Set 3 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pitimbu
# Processing Record 15 of Set 3 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=buala
# Processing Record 16 of Set 3 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=makakilo city
# Processing Record 17 of Set 3 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kavaratti
# Processing Record 18 of Set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saldanha
# Processing Record 19 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hilo
# Processing Record 20 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pevek
# Processing Record 21 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=talnakh
# Processing Record 22 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=te anau
# Processing Record 23 of Set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bambous virieux
# Processing Record 24 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=maceio
# Processing Record 25 of Set 3 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=wanning
# Processing Record 26 of Set 3 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=taloqan
# Processing Record 27 of Set 3 | taloqan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mehamn
# Processing Record 28 of Set 3 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=billings
# Processing Record 29 of Set 3 | billings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tsiroanomandidy
# Processing Record 30 of Set 3 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lompoc
# Processing Record 31 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=batagay
# Processing Record 32 of Set 3 | batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=dryden
# Processing Record 33 of Set 3 | dryden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kahramanmaras
# Processing Record 34 of Set 3 | kahramanmaras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=slave lake
# Processing Record 35 of Set 3 | slave lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=chokurdakh
# Processing Record 36 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tripoli
# Processing Record 37 of Set 3 | tripoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=eyl
# Processing Record 38 of Set 3 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=shimoda
# Processing Record 39 of Set 3 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mahebourg
# Processing Record 40 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nikolskoye
# Processing Record 41 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port blair
# Processing Record 42 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=harper
# Processing Record 43 of Set 3 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=college
# Processing Record 44 of Set 3 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=spencer
# Processing Record 45 of Set 3 | spencer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sentyabrskiy
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=san patricio
# Processing Record 47 of Set 3 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=laela
# Processing Record 48 of Set 3 | laela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=puri
# Processing Record 49 of Set 3 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=matameye
# Processing Record 50 of Set 3 | matameye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=yirol
# Processing Record 1 of Set 4 | yirol
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=asau
# Processing Record 2 of Set 4 | asau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=torbay
# Processing Record 3 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=meridian
# Processing Record 4 of Set 4 | meridian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=barrow
# Processing Record 5 of Set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=taolanaro
# Processing Record 6 of Set 4 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tirana
# Processing Record 7 of Set 4 | tirana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=gondanglegi
# Processing Record 8 of Set 4 | gondanglegi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vestmannaeyjar
# Processing Record 9 of Set 4 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vaitupu
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=attawapiskat
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=honggang
# Processing Record 12 of Set 4 | honggang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=verkhoyansk
# Processing Record 13 of Set 4 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nalut
# Processing Record 14 of Set 4 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=shelburne
# Processing Record 15 of Set 4 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tyret pervaya
# Processing Record 16 of Set 4 | tyret pervaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=katsuura
# Processing Record 17 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hamilton
# Processing Record 18 of Set 4 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=airai
# Processing Record 19 of Set 4 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=riohacha
# Processing Record 20 of Set 4 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kozlovo
# Processing Record 21 of Set 4 | kozlovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kokopo
# Processing Record 22 of Set 4 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=faanui
# Processing Record 23 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=abay
# Processing Record 24 of Set 4 | abay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tombouctou
# Processing Record 25 of Set 4 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=fare
# Processing Record 26 of Set 4 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sioux lookout
# Processing Record 27 of Set 4 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sao joao da barra
# Processing Record 28 of Set 4 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=agva
# Processing Record 29 of Set 4 | agva
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=souillac
# Processing Record 30 of Set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=natulongan
# Processing Record 31 of Set 4 | natulongan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=morant bay
# Processing Record 32 of Set 4 | morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=aldan
# Processing Record 33 of Set 4 | aldan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vanimo
# Processing Record 34 of Set 4 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bundaberg
# Processing Record 35 of Set 4 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=marystown
# Processing Record 36 of Set 4 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tuktoyaktuk
# Processing Record 37 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=beroroha
# Processing Record 38 of Set 4 | beroroha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=okhotsk
# Processing Record 39 of Set 4 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=san jeronimo
# Processing Record 40 of Set 4 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hithadhoo
# Processing Record 41 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=marsh harbour
# Processing Record 42 of Set 4 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=xining
# Processing Record 43 of Set 4 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=alofi
# Processing Record 44 of Set 4 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port macquarie
# Processing Record 45 of Set 4 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=namwala
# Processing Record 46 of Set 4 | namwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=longyearbyen
# Processing Record 47 of Set 4 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port-de-paix
# Processing Record 48 of Set 4 | port-de-paix
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=manggar
# Processing Record 49 of Set 4 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nagato
# Processing Record 50 of Set 4 | nagato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=luang prabang
# Processing Record 1 of Set 5 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hobyo
# Processing Record 2 of Set 5 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kostomuksha
# Processing Record 3 of Set 5 | kostomuksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pithiviers
# Processing Record 4 of Set 5 | pithiviers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=batagay-alyta
# Processing Record 5 of Set 5 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=chicama
# Processing Record 6 of Set 5 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=aiyira
# Processing Record 7 of Set 5 | aiyira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=charters towers
# Processing Record 8 of Set 5 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=longlac
# Processing Record 9 of Set 5 | longlac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ojinaga
# Processing Record 10 of Set 5 | ojinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mitu
# Processing Record 11 of Set 5 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=elko
# Processing Record 12 of Set 5 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=carnarvon
# Processing Record 13 of Set 5 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=yaan
# Processing Record 14 of Set 5 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=la gomera
# Processing Record 15 of Set 5 | la gomera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=solvychegodsk
# Processing Record 16 of Set 5 | solvychegodsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=jatibarang
# Processing Record 17 of Set 5 | jatibarang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=at-bashi
# Processing Record 18 of Set 5 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=noumea
# Processing Record 19 of Set 5 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lebu
# Processing Record 20 of Set 5 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=quatre cocos
# Processing Record 21 of Set 5 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ahipara
# Processing Record 22 of Set 5 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saint-augustin
# Processing Record 23 of Set 5 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kodinsk
# Processing Record 24 of Set 5 | kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lavrentiya
# Processing Record 25 of Set 5 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=camana
# Processing Record 26 of Set 5 | camana
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bredasdorp
# Processing Record 27 of Set 5 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=iguape
# Processing Record 28 of Set 5 | iguape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=gazni
# Processing Record 29 of Set 5 | gazni
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=taburi
# Processing Record 30 of Set 5 | taburi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=medea
# Processing Record 31 of Set 5 | medea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hasaki
# Processing Record 32 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=yar-sale
# Processing Record 33 of Set 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=turiacu
# Processing Record 34 of Set 5 | turiacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bielsk podlaski
# Processing Record 35 of Set 5 | bielsk podlaski
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=achisay
# Processing Record 36 of Set 5 | achisay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=canico
# Processing Record 37 of Set 5 | canico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=steinbach
# Processing Record 38 of Set 5 | steinbach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=victoria
# Processing Record 39 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lincoln
# Processing Record 40 of Set 5 | lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=skelleftea
# Processing Record 41 of Set 5 | skelleftea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=aklavik
# Processing Record 42 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ponta delgada
# Processing Record 43 of Set 5 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tubruq
# Processing Record 44 of Set 5 | tubruq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=stornoway
# Processing Record 45 of Set 5 | stornoway
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=north battleford
# Processing Record 46 of Set 5 | north battleford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=samarai
# Processing Record 47 of Set 5 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tamandare
# Processing Record 48 of Set 5 | tamandare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=calama
# Processing Record 49 of Set 5 | calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=san pedro
# Processing Record 50 of Set 5 | san pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=keuruu
# Processing Record 1 of Set 6 | keuruu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=husavik
# Processing Record 2 of Set 6 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port augusta
# Processing Record 3 of Set 6 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=puerto ayora
# Processing Record 4 of Set 6 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lucea
# Processing Record 5 of Set 6 | lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tapaua
# Processing Record 6 of Set 6 | tapaua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kodiak
# Processing Record 7 of Set 6 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bella union
# Processing Record 8 of Set 6 | bella union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mattru
# Processing Record 9 of Set 6 | mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nagapattinam
# Processing Record 10 of Set 6 | nagapattinam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=acari
# Processing Record 11 of Set 6 | acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nizhneyansk
# Processing Record 12 of Set 6 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=venustiano carranza
# Processing Record 13 of Set 6 | venustiano carranza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=fortuna
# Processing Record 14 of Set 6 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=chuy
# Processing Record 15 of Set 6 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pacifica
# Processing Record 16 of Set 6 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tiksi
# Processing Record 17 of Set 6 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=olafsvik
# Processing Record 18 of Set 6 | olafsvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cabo san lucas
# Processing Record 19 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=artyk
# Processing Record 20 of Set 6 | artyk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=orzhytsya
# Processing Record 21 of Set 6 | orzhytsya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ostrovnoy
# Processing Record 22 of Set 6 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=taksimo
# Processing Record 23 of Set 6 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ugoofaaru
# Processing Record 24 of Set 6 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=haines junction
# Processing Record 25 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=finote selam
# Processing Record 26 of Set 6 | finote selam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sola
# Processing Record 27 of Set 6 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=shushtar
# Processing Record 28 of Set 6 | shushtar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bacolod
# Processing Record 29 of Set 6 | bacolod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=rock sound
# Processing Record 30 of Set 6 | rock sound
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=coquimbo
# Processing Record 31 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=iskateley
# Processing Record 32 of Set 6 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=udachnyy
# Processing Record 33 of Set 6 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sattahip
# Processing Record 34 of Set 6 | sattahip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lumphat
# Processing Record 35 of Set 6 | lumphat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=wajid
# Processing Record 36 of Set 6 | wajid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=havelock
# Processing Record 37 of Set 6 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=caramay
# Processing Record 38 of Set 6 | caramay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=abu zabad
# Processing Record 39 of Set 6 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=grand river south east
# Processing Record 40 of Set 6 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=coldwater
# Processing Record 41 of Set 6 | coldwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vila
# Processing Record 42 of Set 6 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tessalit
# Processing Record 43 of Set 6 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=faya
# Processing Record 44 of Set 6 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=rawson
# Processing Record 45 of Set 6 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=alice springs
# Processing Record 46 of Set 6 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sao filipe
# Processing Record 47 of Set 6 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nyurba
# Processing Record 48 of Set 6 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=owase
# Processing Record 49 of Set 6 | owase
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=la tuque
# Processing Record 50 of Set 6 | la tuque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=port-gentil
# Processing Record 1 of Set 7 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vila franca do campo
# Processing Record 2 of Set 7 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=poya
# Processing Record 3 of Set 7 | poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=menongue
# Processing Record 4 of Set 7 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kruisfontein
# Processing Record 5 of Set 7 | kruisfontein
# ...
# Processing Record 35 of Set 10 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pyapon
# Processing Record 36 of Set 10 | pyapon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=rabo de peixe
# Processing Record 37 of Set 10 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=khasan
# Processing Record 38 of Set 10 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=viedma
# Processing Record 39 of Set 10 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=micheweni
# Processing Record 40 of Set 10 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=portland
# Processing Record 41 of Set 10 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pathum thani
# Processing Record 42 of Set 10 | pathum thani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nedjo
# Processing Record 43 of Set 10 | nedjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=okha
# Processing Record 44 of Set 10 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cayenne
# Processing Record 45 of Set 10 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ambilobe
# Processing Record 46 of Set 10 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=brindisi
# Processing Record 47 of Set 10 | brindisi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=mandera
# Processing Record 48 of Set 10 | mandera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kathmandu
# Processing Record 49 of Set 10 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bilma
# Processing Record 50 of Set 10 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=vinh
# Processing Record 1 of Set 11 | vinh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=acapulco
# Processing Record 2 of Set 11 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ranong
# Processing Record 3 of Set 11 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=diego de almagro
# Processing Record 4 of Set 11 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=fallon
# Processing Record 5 of Set 11 | fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=fort-shevchenko
# Processing Record 6 of Set 11 | fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cardston
# Processing Record 7 of Set 11 | cardston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nizhneudinsk
# Processing Record 8 of Set 11 | nizhneudinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=karamay
# Processing Record 9 of Set 11 | karamay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=marsa matruh
# Processing Record 10 of Set 11 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=severo-kurilsk
# Processing Record 11 of Set 11 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ijaki
# Processing Record 12 of Set 11 | ijaki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=roma
# Processing Record 13 of Set 11 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ginir
# Processing Record 14 of Set 11 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=san isidro
# Processing Record 15 of Set 11 | san isidro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=shenjiamen
# Processing Record 16 of Set 11 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=havoysund
# Processing Record 17 of Set 11 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nelson bay
# Processing Record 18 of Set 11 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=warqla
# Processing Record 19 of Set 11 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kieta
# Processing Record 20 of Set 11 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=robertsport
# Processing Record 21 of Set 11 | robertsport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=seabra
# Processing Record 22 of Set 11 | seabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=saryozek
# Processing Record 23 of Set 11 | saryozek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=smolenskoye
# Processing Record 24 of Set 11 | smolenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=birpur
# Processing Record 25 of Set 11 | birpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=falealupo
# Processing Record 26 of Set 11 | falealupo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=geresk
# Processing Record 27 of Set 11 | geresk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cairns
# Processing Record 28 of Set 11 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ruatoria
# Processing Record 29 of Set 11 | ruatoria
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=innisfail
# Processing Record 30 of Set 11 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nioaque
# Processing Record 31 of Set 11 | nioaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kajaani
# Processing Record 32 of Set 11 | kajaani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sandakan
# Processing Record 33 of Set 11 | sandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=jumla
# Processing Record 34 of Set 11 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=altamont
# Processing Record 35 of Set 11 | altamont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=arman
# Processing Record 36 of Set 11 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=forest acres
# Processing Record 37 of Set 11 | forest acres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=samalaeulu
# Processing Record 38 of Set 11 | samalaeulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=acajutla
# Processing Record 39 of Set 11 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=liku
# Processing Record 40 of Set 11 | liku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=wadi musa
# Processing Record 41 of Set 11 | wadi musa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=aljezur
# Processing Record 42 of Set 11 | aljezur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bowen
# Processing Record 43 of Set 11 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ahuimanu
# Processing Record 44 of Set 11 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=cabedelo
# Processing Record 45 of Set 11 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bilibino
# Processing Record 46 of Set 11 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=panzhihua
# Processing Record 47 of Set 11 | panzhihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sarangani
# Processing Record 48 of Set 11 | sarangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=whitianga
# Processing Record 49 of Set 11 | whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tazovskiy
# Processing Record 50 of Set 11 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=ozark
# Processing Record 1 of Set 12 | ozark
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=borama
# Processing Record 2 of Set 12 | borama
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=paita
# Processing Record 3 of Set 12 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=terme
# Processing Record 4 of Set 12 | terme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=wladyslawowo
# Processing Record 5 of Set 12 | wladyslawowo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=palabuhanratu
# Processing Record 6 of Set 12 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=darhan
# Processing Record 7 of Set 12 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=macklin
# Processing Record 8 of Set 12 | macklin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=lipari
# Processing Record 9 of Set 12 | lipari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=yulara
# Processing Record 10 of Set 12 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=banposh
# Processing Record 11 of Set 12 | banposh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=zhangjiakou
# Processing Record 12 of Set 12 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=dawlatabad
# Processing Record 13 of Set 12 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=borogontsy
# Processing Record 14 of Set 12 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=makungu
# Processing Record 15 of Set 12 | makungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=hinton
# Processing Record 16 of Set 12 | hinton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=sabang
# Processing Record 17 of Set 12 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=phonhong
# Processing Record 18 of Set 12 | phonhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=dauphin
# Processing Record 19 of Set 12 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=murmashi
# Processing Record 20 of Set 12 | murmashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=peleduy
# Processing Record 21 of Set 12 | peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=tiarei
# Processing Record 22 of Set 12 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=bengkulu
# Processing Record 23 of Set 12 | bengkulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=imbituba
# Processing Record 24 of Set 12 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kuruman
# Processing Record 25 of Set 12 | kuruman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=rungata
# Processing Record 26 of Set 12 | rungata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=horsham
# Processing Record 27 of Set 12 | horsham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=akureyri
# Processing Record 28 of Set 12 | akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=karratha
# Processing Record 29 of Set 12 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=klaksvik
# Processing Record 30 of Set 12 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=nemuro
# Processing Record 31 of Set 12 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=broome
# Processing Record 32 of Set 12 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=pulandian
# Processing Record 33 of Set 12 | pulandian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=kununurra
# Processing Record 34 of Set 12 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=amahai
# Processing Record 35 of Set 12 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75a710990aeca6fdf17281cc0cc858fe&q=benton
# Processing Record 36 of Set 12 | benton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(50)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Butaritari   3.07  172.79     85.28        76         100       15.26
# 1      Bathsheba  13.22  -59.52     80.60        69          75       14.99
# 2    Yellowknife  62.45 -114.38    -13.00        75          40        6.93
# 3     Kaitangata -46.28  169.85     48.99        72          80       17.00
# 4       Newberry  46.35  -85.51     32.00        92          90       11.41
# 5         Avarua -21.21 -159.78     80.60        88         100        8.05
# 6       Luderitz -26.65   15.16     63.55        85           0       24.99
# 7          Kapaa  22.08 -159.32     78.80        74          20       11.95
# 8          Bluff -23.58  149.07     74.39        77           0       10.36
# 9        Istmina   5.16  -76.69     86.00        70          75        2.57
# 10  Punta Arenas -53.16  -70.91     57.20        47          40       25.28
# 11   New Norfolk -42.78  147.06     54.00        76          20        9.17
# 12      Sisimiut  66.94  -53.67     -1.30        96         100        6.71
# 13  Saint George  39.45   22.34     42.80        80          90       11.41
# 14      Poshtove  49.79   28.10     30.07        88         100       11.92
# 15        Narsaq  60.91  -46.05     15.80        61          20        8.05
# 16        Albany  42.65  -73.75     35.01        50          40       19.46
# 17     Busselton -33.64  115.35     60.01        40           0        9.35
# 18       Ushuaia -54.81  -68.31     51.80        76          75       32.21
# 19     Cape Town -33.93   18.42     68.00        82          75        9.17
# 20     Saskylakh  71.97  114.09    -19.21        94           0       13.09
# 21         Bijie  27.30  105.30     41.99        95         100        5.41
# 22         Vaini  15.34   74.49     66.11        79           0        6.89
# 23    Nanortalik  60.14  -45.24     26.40        70           0       11.77
# 24         Kyren  51.68  102.13      3.09        72           0        5.23
# 25     Ilulissat  69.22  -51.10      8.60        71          75        5.82
# 26      Almaznyy  48.03   40.04     33.80       100          75        4.47
# 27       Rikitea -23.12 -134.97     76.03        78          67       15.41
# 28       Kibondo  -3.59   30.72     64.11        92         100        1.92
# 29  Port Hedland -20.31  118.58     84.20        74          90       10.29
# 30      Thompson  55.74  -97.86      5.00        84          90        6.93
# 31     Raudeberg  61.99    5.14     48.00       100          75       17.22
# 32       Mataura -46.19  168.86     48.00        85          87       21.00
# 33        Baykit  61.68   96.39      9.34        96         100        4.05
# 34         Aswan  24.09   32.90     46.00        41           0        6.64
# 35       Salinas  36.67 -121.66     57.99        76           1        3.36
# 36      Hermanus -34.42   19.24     64.00        89         100       11.03
# 37        Japura  -0.42  102.29     72.21        96           1        2.26
# 38         Cabra  37.47   -4.43     45.00        93           0        2.04
# 39     Jamestown -33.21  138.60     56.25        87          89        5.93
# 40       Labuhan  -2.54  115.51     72.39        95         100        2.39
# 41          Atar  20.52  -13.05     56.75        22           0        8.41
# 42        Samana   0.12  -76.97     91.40        55          40        5.82
# 43      Zhigansk  66.77  123.37    -10.32        94         100       15.64
# 44    Balikpapan  -1.24  116.86     73.87        96         100        5.32
# 45     Ewa Beach  21.32 -158.01     77.00        83          90        4.70
# 46      Khatanga  71.98  102.47     -8.95        88         100        6.80
# 47     Quelimane -17.88   36.89     82.40        83          75        3.36
# 48     Wonthaggi -38.60  145.59     55.00        95         100        6.53
# 49   Clyde River  70.47  -68.59    -41.80        57          20        4.70
#
#    Country          Current Description  Rain inches (last 3 hrs)  \
# 0       KI                moderate rain                      3.81
# 1       BB  light intensity shower rain                      0.00
# 2       CA             scattered clouds                      0.00
# 3       NZ                   light rain                      1.19
# 4       US                   light snow                      0.00
# 5       CK                   light rain                      0.75
# 6       NA                    clear sky                      0.00
# 7       US                   few clouds                      0.00
# 8       AU                    clear sky                      0.00
# 9       CO                broken clouds                      0.00
# 10      CL             scattered clouds                      0.00
# 11      AU                   few clouds                      0.00
# 12      GL                   light snow                      0.00
# 13      GR              overcast clouds                      0.00
# 14      UA                   light snow                      0.00
# 15      GL                   few clouds                      0.00
# 16      US             scattered clouds                      0.00
# 17      AU                    clear sky                      0.00
# 18      AR                  shower rain                      0.00
# 19      ZA                broken clouds                      0.00
# 20      RU                    clear sky                      0.00
# 21      CN                   light rain                      2.13
# 22      IN                    clear sky                      0.00
# 23      GL                    clear sky                      0.00
# 24      RU                    clear sky                      0.00
# 25      GL                   light snow                      0.00
# 26      RU                   light rain                      0.00
# 27      PF                broken clouds                      0.00
# 28      TZ                   light rain                      2.13
# 29      AU              overcast clouds                      0.00
# 30      CA                   light snow                      0.00
# 31      NO                moderate rain                      0.00
# 32      NZ                   light rain                      1.56
# 33      RU              overcast clouds                      0.00
# 34      EG                    clear sky                      0.00
# 35      US                    clear sky                      0.00
# 36      ZA              overcast clouds                      0.00
# 37      ID                    clear sky                      0.00
# 38      ES                    clear sky                      0.00
# 39      AU                   light rain                      2.19
# 40      ID                moderate rain                      3.06
# 41      MR                    clear sky                      0.00
# 42      EC             scattered clouds                      0.00
# 43      RU              overcast clouds                      0.00
# 44      ID              overcast clouds                      0.00
# 45      US      light intensity drizzle                      0.00
# 46      RU              overcast clouds                      0.00
# 47      MZ                broken clouds                      0.00
# 48      AU                   light rain                      1.00
# 49      CA                   few clouds                      0.00
#
#     Snow inches (last 3 hrs)                 Date
# 0                       0.00  2020-01-05 19:59:34
# 1                       0.00  2020-01-05 19:59:35
# 2                       0.00  2020-01-05 19:55:10
# 3                       0.00  2020-01-05 19:58:52
# 4                       0.00  2020-01-05 19:59:35
# 5                       0.00  2020-01-05 19:59:35
# 6                       0.00  2020-01-05 19:59:17
# 7                       0.00  2020-01-05 19:59:35
# 8                       0.00  2020-01-05 19:59:35
# 9                       0.00  2020-01-05 19:59:35
# 10                      0.00  2020-01-05 19:59:35
# 11                      0.00  2020-01-05 19:59:35
# 12                      0.56  2020-01-05 19:59:36
# 13                      0.00  2020-01-05 19:59:20
# 14                      0.19  2020-01-05 19:59:36
# 15                      0.00  2020-01-05 19:59:36
# 16                      0.00  2020-01-05 19:54:43
# 17                      0.00  2020-01-05 19:59:36
# 18                      0.00  2020-01-05 19:59:36
# 19                      0.00  2020-01-05 19:56:02
# 20                      0.00  2020-01-05 19:59:36
# 21                      0.00  2020-01-05 19:59:36
# 22                      0.00  2020-01-05 19:59:36
# 23                      0.00  2020-01-05 19:59:37
# 24                      0.00  2020-01-05 19:59:37
# 25                      0.00  2020-01-05 19:58:57
# 26                      0.00  2020-01-05 19:59:37
# 27                      0.00  2020-01-05 19:59:37
# 28                      0.00  2020-01-05 19:59:37
# 29                      0.00  2020-01-05 19:59:30
# 30                      0.00  2020-01-05 19:59:37
# 31                      0.00  2020-01-05 19:59:37
# 32                      0.00  2020-01-05 19:55:16
# 33                      0.00  2020-01-05 19:59:37
# 34                      0.00  2020-01-05 19:59:37
# 35                      0.00  2020-01-05 19:59:37
# 36                      0.00  2020-01-05 19:59:38
# 37                      0.00  2020-01-05 19:59:38
# 38                      0.00  2020-01-05 19:59:38
# 39                      0.00  2020-01-05 19:59:38
# 40                      0.00  2020-01-05 19:59:38
# 41                      0.00  2020-01-05 19:59:38
# 42                      0.00  2020-01-05 19:59:38
# 43                      0.00  2020-01-05 19:59:39
# 44                      0.00  2020-01-05 19:59:39
# 45                      0.00  2020-01-05 19:56:59
# 46                      0.00  2020-01-05 19:59:39
# 47                      0.00  2020-01-05 19:59:39
# 48                      0.00  2020-01-05 19:59:39
# 49                      0.00  2020-01-05 19:59:39

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# How many cities have recorded rainfall?
city_rain = len(city_data_df[city_data_df["Rain inches (last 3 hrs)"]>0])

print(f"The count of cities with recorded rainfall - {city_rain}.")
# Out:
# The count of cities with recorded rainfall - 55.

# %%
#How many cities have recorded snow
city_snow = len(city_data_df[city_data_df["Snow inches (last 3 hrs)"]>0])
print(f"The count of cities with recorded snow - {city_snow}.")
# Out:
# The count of cities with recorded snow - 22.
